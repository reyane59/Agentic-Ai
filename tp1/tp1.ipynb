# %%
import tiktoken
from dotenv import load_dotenv
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
# Out:
# True

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4o")
print(tokenizer.name)
# Out:
# o200k_base

# %%
tokenizer = tiktoken.get_encoding("o200k_base")

# %%
prompt = "tu es un expert en mathématiques"

# %%
tokens = tokenizer.encode(prompt)

# %%
print(len(tokens))
# Out:
# 7

# %%
for token in tokens : 
    t= tokenizer.decode_single_token_bytes(token).decode("utf-8")
    print(t)
# Out:
# tu
#  es
#  un
#  expert
#  en
#  math
# ématiques

# %%
def token_count (prompt:str, model:str="o200k_base"):
    tokenizer = tiktoken.get_encoding(model)
    return len(tokenizer.encode(prompt))

# %%
print(token_count(prompt="vous êtes un expert en mathématiques"))
# Out:
# 7

# %%
from langchain_openai import ChatOpenAI
import os

# %%
print(os.environ['OPENAI_API_KEY'])
# Out:
# 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

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
resp = llm.invoke(input=[
    {"role":"system", "content":"tu es un expert en mathématiques"},
    {"role":"user", "content":"explique moi les suites de Fibonacci"}
])

# %%
print(display(Markdown(resp.content)))
# Out:
# Les suites de Fibonacci sont une célèbre séquence de nombres où chaque nombre est la somme des deux précédents. Elle commence généralement par 0 et 1. Voici comment elle se développe :
#
# - \( F_0 = 0 \)
# - \( F_1 = 1 \)
# - Pour \( n \geq 2 \), \( F_n = F_{n-1} + F_{n-2} \)
#
# Ainsi, les premiers termes de la suite de Fibonacci sont :
#
# - \( F_0 = 0 \)
# - \( F_1 = 1 \)
# - \( F_2 = 1 \) (car \( 0 + 1 = 1 \))
# - \( F_3 = 2 \) (car \( 1 + 1 = 2 \))
# - \( F_4 = 3 \) (car \( 1 + 2 = 3 \))
# - \( F_5 = 5 \) (car \( 2 + 3 = 5 \))
# - \( F_6 = 8 \) (car \( 3 + 5 = 8 \))
# - Et ainsi de suite...
#
# La suite de Fibonacci apparaît dans de nombreux domaines des mathématiques et des sciences, notamment en biologie, en art et en architecture. Elle est également liée au nombre d'or, souvent noté \( \phi \), car le rapport entre deux termes consécutifs de la suite tend vers ce nombre à mesure que l'on avance dans la suite. Le nombre d'or est approximativement égal à 1,6180339887...
#
# La suite de Fibonacci est également utilisée dans divers algorithmes et structures de données en informatique, et elle a des propriétés intéressantes en théorie des nombres.
# None
